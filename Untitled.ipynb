# %%
import yfinance as yf

# Extract Tesla stock data
tesla_data = yf.download('TSLA', start='2022-01-01', end='2022-12-31')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import requests
from bs4 import BeautifulSoup

# Web scrape Tesla revenue data
url = 'https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find('table', class_='historical_data_table')
# Parse table data and extract revenue
# You may need to adjust this based on the actual HTML structure of the webpage

# %%
# Extract GameStop stock data
gamestop_data = yf.download('GME', start='2022-01-01', end='2022-12-31')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Web scrape GameStop revenue data
url = 'https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find('table', class_='historical_data_table')
# Parse table data and extract revenue
# You may need to adjust this based on the actual HTML structure of the webpage

# %%
import matplotlib.pyplot as plt

# Create Tesla stock and revenue dashboard
plt.figure(figsize=(10, 6))
plt.plot(tesla_data['Close'], label='Close Price')
# Plot Tesla revenue data
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Tesla Stock and Revenue Dashboard')
plt.legend()
plt.show()

# %%
# Create GameStop stock and revenue dashboard
plt.figure(figsize=(10, 6))
plt.plot(gamestop_data['Close'], label='Close Price')
# Plot GameStop revenue data
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('GameStop Stock and Revenue Dashboard')
plt.legend()
plt.show()
